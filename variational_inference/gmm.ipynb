# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import MultivariateGaussianMixture, EMGaussianMixture, ExponentialNormalNDGenerator

# %%
# Initialize the generator with lambda = 2 and default dim=2
generator = ExponentialNormalNDGenerator(lam=1, dim=1)

# Generate 1000 samples
z, x = generator.generate_data(num_samples=100000)

# Plot the data
generator.plot_data(z, x)

# Plot the scatter plot
generator.plot_scatter(z, x)

# %%
gmm_generator = MultivariateGaussianMixture(num_components=5, num_samples=1000, dim=2)
x, z, mu, theta = gmm_generator.generate_data()
gmm_generator.plot_data(x, z, mu)

# %%
EM = EMGaussianMixture(x, num_components=5)
pi, mu, Sigma = EM.fit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 EM = EMGaussianMixture(x, num_components=5, num_iters=100, tol=1e-3)
#       2 pi, mu, Sigma = EM.fit()
#
# TypeError: EMGaussianMixture.__init__() got multiple values for argument 'num_components'
