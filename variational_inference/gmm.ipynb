# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import MultivariateGaussianMixture, EMGaussianMixture

# %%
gmm_generator = MultivariateGaussianMixture(num_components=8, num_samples=300, dim=2)
x, z, mu, theta = gmm_generator.generate_data()
gmm_generator.plot_data(x, z, mu)
